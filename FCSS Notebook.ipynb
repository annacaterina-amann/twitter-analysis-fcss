# %%
# needed installs
# !pip install scipy==1.8.0
# !pip install networkx
# !pip install matplotlib
# !pip install nltk

# needed imports and downloads
import nltk
nltk.download('vader_lexicon')
import networkx as nx
#from networkx.algorithms.community.centrality import girvan_newman
import networkx.algorithms.community as nx_comm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter
import re
# Out:
# Collecting scipy==1.8.0
#   Downloading scipy-1.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 36.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scipy==1.8.0) (1.23.4)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Not uninstalling scipy at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'scipy'. No files were found to uninstall.
# Successfully installed scipy-1.8.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Collecting networkx
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.7 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (2022.9.13)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %% [markdown]
# ## Dataframe creation and data cleaning

# %%
# loading the csv into a dataframe
df = pd.read_csv('/work/sentiment.csv')
df.head()
# Out:
#    Unnamed: 0                       Date                   ID  \
# 0           0  2022-12-17 23:46:34+00:00  1604261802715611137
# 1           1  2022-12-17 23:43:31+00:00  1604261035841568772
# 2           2  2022-12-17 23:41:29+00:00  1604260523977183233
# 3           3  2022-12-17 23:34:04+00:00  1604258660133240832
# 4           4  2022-12-17 23:23:23+00:00  1604255971630538752
#
#                                                  url         username  \
# 0  https://twitter.com/HaraldV7/status/1604261802...         HaraldV7
# 1  https://twitter.com/HeadSoccer_Main/status/160...  HeadSoccer_Main
# 2  https://twitter.com/BunteRepDE/status/16042605...       BunteRepDE
# 3  https://twitter.com/emojizedcom/status/1604258...      emojizedcom
# 4  https://twitter.com/PaulMll06935330/status/160...  PaulMll06935330
#
#                 source             location  \
# 0  Twitter for Android                  NaN
# 1  Twitter for Android            Unbekannt
# 2   Twitter for iPhone                  NaN
# 3    WP Plugin Dev Com  Zurich, Switzerland
# 4  Twitter for Android                  NaN
#
#                                                tweet  num of likes  \
# 0  @MarcoBuschmann Die Straftaten machen die Poli...             0
# 1  Bitte retweeten was das Zeug hält.\nOben die d...            12
# 2  #GrüneSekte + #LetzteGeneration https://t.co/e...             8
# 3  #Klimaaktivisten, #Klimakleber sind spinner!💻 ...             0
# 4  @ThatDataStuff @MDRAktuell Diese #LetzteGenera...             2
#
#    num of retweets
# 0                0
# 1                8
# 2                1
# 3                0
# 4                0

# %%
# check if there are duplicated rows in the dataframe
duplicateRows = df[df.duplicated()]

duplicateRows
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, ID, url, username, source, location, tweet, num of likes, num of retweets]
# Index: []

# %%
# define a regular expression to match usernames
username_regex = r'@(\w+)'

# apply the regular expression to each row of the 'tweet' column using the str.findall() method
df['interacted_user'] = df['tweet'].apply(lambda x: set(re.findall(username_regex, x)))

# print the first 5 rows of the updated dataframe
df.head()
# Out:
#    Unnamed: 0                       Date                   ID  \
# 0           0  2022-12-17 23:46:34+00:00  1604261802715611137
# 1           1  2022-12-17 23:43:31+00:00  1604261035841568772
# 2           2  2022-12-17 23:41:29+00:00  1604260523977183233
# 3           3  2022-12-17 23:34:04+00:00  1604258660133240832
# 4           4  2022-12-17 23:23:23+00:00  1604255971630538752
#
#                                                  url         username  \
# 0  https://twitter.com/HaraldV7/status/1604261802...         HaraldV7
# 1  https://twitter.com/HeadSoccer_Main/status/160...  HeadSoccer_Main
# 2  https://twitter.com/BunteRepDE/status/16042605...       BunteRepDE
# 3  https://twitter.com/emojizedcom/status/1604258...      emojizedcom
# 4  https://twitter.com/PaulMll06935330/status/160...  PaulMll06935330
#
#                 source             location  \
# 0  Twitter for Android                  NaN
# 1  Twitter for Android            Unbekannt
# 2   Twitter for iPhone                  NaN
# 3    WP Plugin Dev Com  Zurich, Switzerland
# 4  Twitter for Android                  NaN
#
#                                                tweet  num of likes  \
# 0  @MarcoBuschmann Die Straftaten machen die Poli...             0
# 1  Bitte retweeten was das Zeug hält.\nOben die d...            12
# 2  #GrüneSekte + #LetzteGeneration https://t.co/e...             8
# 3  #Klimaaktivisten, #Klimakleber sind spinner!💻 ...             0
# 4  @ThatDataStuff @MDRAktuell Diese #LetzteGenera...             2
#
#    num of retweets              interacted_user
# 0                0             {MarcoBuschmann}
# 1                8                           {}
# 2                1                           {}
# 3                0                           {}
# 4                0  {MDRAktuell, ThatDataStuff}

# %%
# some users in interacted user are not in the username column
# this user need to be filtered out as to only have valid user to user interactions
unique_interacted_user =  set()

for in_set in df.interacted_user:
    for i in in_set: 
        unique_interacted_user.add(i)


username = set()
for i in df.username: 
    username.add(i)

# user that are mentioned in tweets but not part of the original dataset = non_user
non_user = set(unique_interacted_user.difference(username))

print(f" {len(unique_interacted_user)} number unique interacted_user")
print(f" {len(unique_interacted_user.difference(username))} number unique interacted_user not found in username column")
print(f" {len(non_user)} length non_user set to verify number of usernames not in username column")
print(f" user left: {len(unique_interacted_user)-len(non_user)}")
# Out:
#  1518 number unique interacted_user
#  1132 number unique interacted_user not found in username column
#  1132 length non_user set to verify number of usernames not in username column
#  user left: 386

# %%
# new dataframe with only valid user in username and interacted_user columns
cleanedInteractedUserDF = df.copy()
cleanedInteractedUserDF['interacted_user'] = [set(x).difference(non_user) for x in cleanedInteractedUserDF['interacted_user']]

test_unique_interacted_user =  set()

for in_set in cleanedInteractedUserDF['interacted_user']:
    for i in in_set: 
        test_unique_interacted_user.add(i)
print(len(test_unique_interacted_user))
# Out:
# 386

# %%
# some rows have now no interacted_user in order to have valid user to user interactions
# rows without interacted_user are filtered out
mask = cleanedInteractedUserDF['interacted_user'].apply(lambda x: len(x) == 0)

# filter the DataFrame using the mask
noEmptySetDF = cleanedInteractedUserDF[~mask]

# new dataframe with no empty interacted_user column
noEmptySetDF.head()
# Out:
#     Unnamed: 0                       Date                   ID  \
# 0            0  2022-12-17 23:46:34+00:00  1604261802715611137
# 5            5  2022-12-17 23:20:48+00:00  1604255318690516992
# 7            7  2022-12-17 23:05:54+00:00  1604251567980412932
# 8            8  2022-12-17 22:50:36+00:00  1604247719001952256
# 12          12  2022-12-17 22:38:46+00:00  1604244741318758402
#
#                                                   url    username  \
# 0   https://twitter.com/HaraldV7/status/1604261802...    HaraldV7
# 5   https://twitter.com/Ein_Trixi/status/160425531...   Ein_Trixi
# 7   https://twitter.com/Nette_0870/status/16042515...  Nette_0870
# 8   https://twitter.com/dingendorf/status/16042477...  dingendorf
# 12  https://twitter.com/Kranich631/status/16042447...  Kranich631
#
#                  source                location  \
# 0   Twitter for Android                     NaN
# 5   Twitter for Android                     NaN
# 7       Twitter Web App             Deutschland
# 8   Twitter for Android  Montabaur, Deutschland
# 12      Twitter Web App                     NaN
#
#                                                 tweet  num of likes  \
# 0   @MarcoBuschmann Die Straftaten machen die Poli...             0
# 5   @watch_union @_FriedrichMerz Es ist für Herrn ...             1
# 7   @Michael47439567 @AufstandLastGen Die Rhetorik...             0
# 8   @Meikell56 Der Punkt ist doch, dass es so ist,...             3
# 12  @herbertEXgth @MarcoBuschmann Ich habe nicht g...             0
#
#     num of retweets                 interacted_user
# 0                 0                {MarcoBuschmann}
# 5                 0                   {watch_union}
# 7                 0               {AufstandLastGen}
# 8                 0                     {Meikell56}
# 12                0  {MarcoBuschmann, herbertEXgth}

# %%
# check that our chosen hashtags are contained in the tweets 
# and save the cleaned dataframe in a new dataframe
pattern = '|'.join(['#letztegeneration', '#lastgeneration', '#klimakleber'])
df_cleaned = noEmptySetDF[noEmptySetDF['tweet'].str.contains(pattern, flags=re.IGNORECASE)]
df_cleaned
# Out:
#       Unnamed: 0                       Date                   ID  \
# 0              0  2022-12-17 23:46:34+00:00  1604261802715611137
# 5              5  2022-12-17 23:20:48+00:00  1604255318690516992
# 7              7  2022-12-17 23:05:54+00:00  1604251567980412932
# 8              8  2022-12-17 22:50:36+00:00  1604247719001952256
# 12            12  2022-12-17 22:38:46+00:00  1604244741318758402
# ...          ...                        ...                  ...
# 6642        6642  2022-12-12 06:11:47+00:00  1602184420580118528
# 6645        6645  2022-12-12 05:40:16+00:00  1602176490220781569
# 6664        6664  2022-12-12 01:22:57+00:00  1602111734105649152
# 6666        6666  2022-12-12 00:59:51+00:00  1602105918182887424
# 6667        6667  2022-12-12 00:41:25+00:00  1602101281941848069
#
#                                                     url         username  \
# 0     https://twitter.com/HaraldV7/status/1604261802...         HaraldV7
# 5     https://twitter.com/Ein_Trixi/status/160425531...        Ein_Trixi
# 7     https://twitter.com/Nette_0870/status/16042515...       Nette_0870
# 8     https://twitter.com/dingendorf/status/16042477...       dingendorf
# 12    https://twitter.com/Kranich631/status/16042447...       Kranich631
# ...                                                 ...              ...
# 6642  https://twitter.com/Vizecancler/status/1602184...      Vizecancler
# 6645  https://twitter.com/AlexxTVYT/status/160217649...        AlexxTVYT
# 6664  https://twitter.com/JuergenWelker1/status/1602...   JuergenWelker1
# 6666  https://twitter.com/Markus_Wolff_55/status/160...  Markus_Wolff_55
# 6667  https://twitter.com/UliWeidinger/status/160210...     UliWeidinger
#
#                    source                        location  \
# 0     Twitter for Android                             NaN
# 5     Twitter for Android                             NaN
# 7         Twitter Web App                     Deutschland
# 8     Twitter for Android          Montabaur, Deutschland
# 12        Twitter Web App                             NaN
# ...                   ...                             ...
# 6642      Twitter Web App                             NaN
# 6645      Twitter Web App                   Washington DC
# 6664   Twitter for iPhone                          Bayern
# 6666      Twitter Web App  Auf dem Laufenden hoffentlich!
# 6667   Twitter for iPhone                    Niederbayern
#
#                                                   tweet  num of likes  \
# 0     @MarcoBuschmann Die Straftaten machen die Poli...             0
# 5     @watch_union @_FriedrichMerz Es ist für Herrn ...             1
# 7     @Michael47439567 @AufstandLastGen Die Rhetorik...             0
# 8     @Meikell56 Der Punkt ist doch, dass es so ist,...             3
# 12    @herbertEXgth @MarcoBuschmann Ich habe nicht g...             0
# ...                                                 ...           ...
# 6642  So viel Humor hätte ich der @AufstandLastGen g...             2
# 6645  @VCD_Nord @AufstandLastGen @VCDeV @VCD_Nordost...             3
# 6664  @JostMichael555 @e_stonewell @Regendelfin @ste...             0
# 6666  @wenig_worte RAF trendet. Siehe auch "Klima-RA...             0
# 6667  @Jim_Beau_27 @AufstandLastGen Also unabhängig ...             1
#
#       num of retweets                 interacted_user
# 0                   0                {MarcoBuschmann}
# 5                   0                   {watch_union}
# 7                   0               {AufstandLastGen}
# 8                   0                     {Meikell56}
# 12                  0  {MarcoBuschmann, herbertEXgth}
# ...               ...                             ...
# 6642                0               {AufstandLastGen}
# 6645                0               {AufstandLastGen}
# 6664                0    {JostMichael555, zeitonline}
# 6666                0                   {wenig_worte}
# 6667                0               {AufstandLastGen}
#
# [1739 rows x 11 columns]

# %%
# define a regular expression to match hashtags
hashtag_regex = r'#(\w+)'

# apply the regular expression to each row of the 'tweet' column using the str.findall() method
df_cleaned['hashtag'] = df_cleaned['tweet'].apply(lambda x: set(re.findall(hashtag_regex, x)))

# print the updated dataframe
df_cleaned
# Out:
#       Unnamed: 0                       Date                   ID  \
# 0              0  2022-12-17 23:46:34+00:00  1604261802715611137
# 5              5  2022-12-17 23:20:48+00:00  1604255318690516992
# 7              7  2022-12-17 23:05:54+00:00  1604251567980412932
# 8              8  2022-12-17 22:50:36+00:00  1604247719001952256
# 12            12  2022-12-17 22:38:46+00:00  1604244741318758402
# ...          ...                        ...                  ...
# 6642        6642  2022-12-12 06:11:47+00:00  1602184420580118528
# 6645        6645  2022-12-12 05:40:16+00:00  1602176490220781569
# 6664        6664  2022-12-12 01:22:57+00:00  1602111734105649152
# 6666        6666  2022-12-12 00:59:51+00:00  1602105918182887424
# 6667        6667  2022-12-12 00:41:25+00:00  1602101281941848069
#
#                                                     url         username  \
# 0     https://twitter.com/HaraldV7/status/1604261802...         HaraldV7
# 5     https://twitter.com/Ein_Trixi/status/160425531...        Ein_Trixi
# 7     https://twitter.com/Nette_0870/status/16042515...       Nette_0870
# 8     https://twitter.com/dingendorf/status/16042477...       dingendorf
# 12    https://twitter.com/Kranich631/status/16042447...       Kranich631
# ...                                                 ...              ...
# 6642  https://twitter.com/Vizecancler/status/1602184...      Vizecancler
# 6645  https://twitter.com/AlexxTVYT/status/160217649...        AlexxTVYT
# 6664  https://twitter.com/JuergenWelker1/status/1602...   JuergenWelker1
# 6666  https://twitter.com/Markus_Wolff_55/status/160...  Markus_Wolff_55
# 6667  https://twitter.com/UliWeidinger/status/160210...     UliWeidinger
#
#                    source                        location  \
# 0     Twitter for Android                             NaN
# 5     Twitter for Android                             NaN
# 7         Twitter Web App                     Deutschland
# 8     Twitter for Android          Montabaur, Deutschland
# 12        Twitter Web App                             NaN
# ...                   ...                             ...
# 6642      Twitter Web App                             NaN
# 6645      Twitter Web App                   Washington DC
# 6664   Twitter for iPhone                          Bayern
# 6666      Twitter Web App  Auf dem Laufenden hoffentlich!
# 6667   Twitter for iPhone                    Niederbayern
#
#                                                   tweet  num of likes  \
# 0     @MarcoBuschmann Die Straftaten machen die Poli...             0
# 5     @watch_union @_FriedrichMerz Es ist für Herrn ...             1
# 7     @Michael47439567 @AufstandLastGen Die Rhetorik...             0
# 8     @Meikell56 Der Punkt ist doch, dass es so ist,...             3
# 12    @herbertEXgth @MarcoBuschmann Ich habe nicht g...             0
# ...                                                 ...           ...
# 6642  So viel Humor hätte ich der @AufstandLastGen g...             2
# 6645  @VCD_Nord @AufstandLastGen @VCDeV @VCD_Nordost...             3
# 6664  @JostMichael555 @e_stonewell @Regendelfin @ste...             0
# 6666  @wenig_worte RAF trendet. Siehe auch "Klima-RA...             0
# 6667  @Jim_Beau_27 @AufstandLastGen Also unabhängig ...             1
#
#       num of retweets                 interacted_user  \
# 0                   0                {MarcoBuschmann}
# 5                   0                   {watch_union}
# 7                   0               {AufstandLastGen}
# 8                   0                     {Meikell56}
# 12                  0  {MarcoBuschmann, herbertEXgth}
# ...               ...                             ...
# 6642                0               {AufstandLastGen}
# 6645                0               {AufstandLastGen}
# 6664                0    {JostMichael555, zeitonline}
# 6666                0                   {wenig_worte}
# 6667                0               {AufstandLastGen}
#
#                                                 hashtag
# 0                                    {LetzteGeneration}
# 5                                    {LetzteGeneration}
# 7           {LetzteGeneration, Reichsbürgern, KlimaRAF}
# 8                                    {LetzteGeneration}
# 12                                   {LetzteGeneration}
# ...                                                 ...
# 6642  {Klimaterroristen, Klimakleber, LetzteDegenera...
# 6645                                 {LetzteGeneration}
# 6664                    {Klimakleber, Klimakatastrophe}
# 6666                                 {LetzteGeneration}
# 6667                                      {Klimakleber}
#
# [1739 rows x 12 columns]

# %% [markdown]
# ## Graph Creation

# %%
# convert hashtags to frozensets
df_cleaned['hashtag'] = df_cleaned['hashtag'].apply(lambda x: frozenset(x))



# create a graph
G = nx.Graph()

nodes = df_cleaned[["username", "hashtag"]]
node_list = [
    (row["username"], {"hashtag":row["hashtag"]}) \
    for i, row in nodes.iterrows()
]
G.add_nodes_from(node_list)

# add edges to the graph based on the 'username' and 'interacted_user' columns
for _, row in df_cleaned.iterrows():
    for interacted_user in row['interacted_user']:
        G.add_edge(row['username'], interacted_user)

# apply the Louvain algorithm to detect communities in the graph
communities = nx_comm.louvain_communities(G)

# Add coloring to the communities and plot the graph
N_communities = len(communities)
cmap = plt.get_cmap("Set3")
colors = [cmap(i) for i in range(N_communities)]
color_dict = {community:color for community, color in zip(range(N_communities), colors)}

node_list = []
node_colors = []
for i, community in enumerate(communities):
    for node in community:
        node_list.append(node)
        node_colors.append(color_dict[i])

fig, ax = plt.subplots(figsize=(30, 30))
nx.draw_networkx(
    G, 
    nodelist=node_list,
    node_color=node_colors,
    node_size=70, 
    with_labels=False,
    ax=ax
)

# %% [markdown]
# ## Analysis

# %%
# calculate degree assortativity coefficient
assortativity_org = nx.attribute_assortativity_coefficient(G, 'hashtag')

# print result
print("Assortativity coefficient:", assortativity_org)
# Out:
# Assortativity coefficient: -0.1225447458899121

# %%
# permutation testing: do users tend to connect to other users using the same hashtags? 
# we expect they do! -> Assortativity > 0

# set seed for replication
np.random.seed(12345)

# set number of permutations to 1000
b = 1000

# calculate assortativity coefficient with sampled hashtags
perm_assortativities = []

for i in range(b):
    hashtags = nodes["hashtag"].sample(frac=1).values
    shuffled_labels = {node:hashtag for node, hashtag in zip(nodes["username"], hashtags)}
    nx.set_node_attributes(G, shuffled_labels, name="hashtag")
    perm_assortativities.append(nx.attribute_assortativity_coefficient(G, "hashtag"))

perm_assortativities = np.array(perm_assortativities)

print("Mean assortativity coefficient (1000 Permutations):", perm_assortativities.mean())
# Out:
# Mean assortativity coefficient (1000 Permutations): -0.13839349529321243

# %%
fig, ax = plt.subplots()
ax.hist(perm_assortativities, bins=50, rwidth=0.8, label="permutation test")
ax.axvline(assortativity_org, color="red", label="original assortativity")
ax.set_ylabel("count")
ax.set_xlabel("assortativity 'hashtag'")
ax.legend(loc=9)

# %%
# calculate p-value for H_0: Assortativity <= 0 and H_1: Assortativity is positive and alpha == 0.05

# since permuted assortativities and original assortativities are all negative, we count how many permuted assortativities are even more negative (more extreme)
p_value = (1 + sum(perm_assortativities < assortativity_org)) / len(perm_assortativities)

print("H_0: Assortativity <= 0\nH_1: Assortativity > 0\nlevel of significance: 0.05")
print("Don't reject H_0 with p =", p_value)
print("Interpretation: It is likely that original assortativity result happened by chance.")
# Out:
# H_0: Assortativity <= 0
# H_1: Assortativity > 0
# level of significance: 0.05
# Don't reject H_0 with p = 0.555
# Interpretation: It is likely that original assortativity result happened by chance.

# %%
modularity = nx_comm.modularity(G, communities)
print("Modularity score:", modularity)
# Out:
# Modularity score: 0.6986492014356407

# %%
# sort communities based on size in descending order
c_sorted = sorted(communities, key=lambda x: len(x), reverse=True)

for c in c_sorted:
    if len(c) >2:
     print(len(c))
print(f"number of communities: {len(c_sorted)}")
# Out:
# 270
# 80
# 71
# 63
# 59
# 57
# 55
# 52
# 45
# 43
# 42
# 39
# 38
# 36
# 34
# 30
# 29
# 25
# 24
# 23
# 22
# 15
# 14
# 14
# 5
# 4
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# number of communities: 117

# %%
# print information on the biggest community
# code block can be repurposed for every community by changing the next 4 lines accordingly

biggestCommunity = c_sorted[0]
setVariable = biggestCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

biggestCommunityHashtags = dfVariable['hashtag']

set_biggestCommunityHashtags = set()
for frozen_set in biggestCommunityHashtags:
    for value in frozen_set:
        set_biggestCommunityHashtags.add(value)

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# heino_matthies     36
# Kranich631         12
# Sunnynonumber      11
# berlinerzeitung     7
# ToBeThatGuy_        7
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)                        318
# (Klimakleber)                              28
# (lastgeneration)                           22
# (LastGeneration)                            8
# (letzteDegeneration, LetzteGeneration)      8
# Name: hashtag, dtype: int64
#
# most likes
#      username  num of likes  num of retweets   interacted_user                              hashtag
#  Perowinger94          3863              613 {AufstandLastGen}                   (LetzteGeneration)
#   CaroRackete          3195              484 {AufstandLastGen} (Klimakatastrophe, LetzteGeneration)
# greenpeace_de          1853              338 {AufstandLastGen}  (Klimaaktivismus, LetzteGeneration)
# most retweets
#      username  num of likes  num of retweets   interacted_user                              hashtag
#  Perowinger94          3863              613 {AufstandLastGen}                   (LetzteGeneration)
#   CaroRackete          3195              484 {AufstandLastGen} (Klimakatastrophe, LetzteGeneration)
# greenpeace_de          1853              338 {AufstandLastGen}  (Klimaaktivismus, LetzteGeneration)

# %%
secondCommunity = c_sorted[1]
setVariable = secondCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

secondCommunityHashtags = dfVariable['hashtag']

set_secondCommunityHashtags = set()
for frozen_set in secondCommunityHashtags:
    for value in frozen_set:
        set_secondCommunityHashtags.add(value)

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# 1410_berlin       5
# mannomanleute     4
# LisaKlaster       4
# MBthemaskedone    2
# Kranich631        2
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)                   50
# (Klimakleber)                         4
# (lastgeneration)                      3
# (NieMehrCDUCSU, LetzteGeneration)     2
# (Reichsbürger, LetzteGeneration)      2
# Name: hashtag, dtype: int64
#
# most likes
#        username  num of likes  num of retweets  interacted_user            hashtag
# christophnebgen           287               16 {MarcoBuschmann} (LetzteGeneration)
#   M_J_Salzgeber           190               41 {MarcoBuschmann} (LetzteGeneration)
#       Ma_Heller           137               23 {MarcoBuschmann} (LetzteGeneration)
# most retweets
#        username  num of likes  num of retweets  interacted_user            hashtag
#   M_J_Salzgeber           190               41 {MarcoBuschmann} (LetzteGeneration)
#       Ma_Heller           137               23 {MarcoBuschmann} (LetzteGeneration)
# christophnebgen           287               16 {MarcoBuschmann} (LetzteGeneration)

# %%
thirdCommunity = c_sorted[2]
setVariable = thirdCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# OSchreibt        16
# Marktzyniker     16
# Sunnynonumber    12
# thisisitA123      8
# tomp0213          6
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)    89
# (Klimakleber)          5
# (Letztegeneration)     5
# (lastgeneration)       4
# (LastGeneration)       3
# Name: hashtag, dtype: int64
#
# most likes
#        username  num of likes  num of retweets                    interacted_user            hashtag
# berlinerzeitung           175               42 {AufstandLastGen, carla_hinrichs_} (LetzteGeneration)
# AufstandLastGen           113               16                     {THeatherbell} (LetzteGeneration)
#       OSchreibt            90                8                          {Dzienus} (LetzteGeneration)
# most retweets
#        username  num of likes  num of retweets                    interacted_user                    hashtag
# berlinerzeitung           175               42 {AufstandLastGen, carla_hinrichs_}         (LetzteGeneration)
#       ndaktuell            53               27                        {timluedde} (Berlin, LetzteGeneration)
#     RealTadzioM            40               18                         {bund_net}         (LetzteGeneration)

# %%
fourthCommunity = c_sorted[3]
setVariable = fourthCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# DeTottel           7
# DieMuenchnerin     6
# Timtam792687961    4
# SchwabeVoll        3
# JKitKat651         3
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)                                                    42
# (Politikversagen, Klimawandel, Klimakatastrophe, LetzteGeneration)     3
# (Klimakleber)                                                          2
# (letzteDegeneration, LetzteGeneration)                                 2
# (letzteGeneration)                                                     2
# Name: hashtag, dtype: int64
#
# most likes
#       username  num of likes  num of retweets   interacted_user                                                                           hashtag
#  lukaswallraff           171               53  {tazgezwitscher}                                            (LetzteGeneration, Klimaclub, tazeins)
#       KuhnTimm            64               17 {AufstandLastGen}                                                                (LetzteGeneration)
# parents4future            56               10 {AufstandLastGen} (EndFossilFuels, WirAlleSindDieLetzteGeneration, ClimateCrisis, LetzteGeneration)
# most retweets
#      username  num of likes  num of retweets   interacted_user                                hashtag
# lukaswallraff           171               53  {tazgezwitscher} (LetzteGeneration, Klimaclub, tazeins)
#      KuhnTimm            64               17 {AufstandLastGen}                     (LetzteGeneration)
#      KuhnTimm            22               13      {retep_kire}                     (LetzteGeneration)

# %%
fifthCommunity = c_sorted[4]
setVariable = fifthCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# TheNetscape     8
# XR_Legal        5
# ckXe3           4
# glueckskicks    2
# aggps458        2
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)                                              39
# (lastgeneration)                                                 3
# (Klimakleber)                                                    2
# (klimaaktivismus, schwarwel, Reichsbürger, LetzteGeneration)     2
# (Reichsbürger, LetzteGeneration)                                 2
# Name: hashtag, dtype: int64
#
# most likes
#      username  num of likes  num of retweets   interacted_user                          hashtag
# NikolausBlome           199               21      {derspiegel} (Reichsbürger, LetzteGeneration)
#      wegeheld            35               11 {AufstandLastGen} (friedfertige, LetzteGeneration)
#      nothilfe            23               10 {AufstandLastGen}               (LetzteGeneration)
# most retweets
#      username  num of likes  num of retweets   interacted_user                                          hashtag
# NikolausBlome           199               21      {derspiegel}                 (Reichsbürger, LetzteGeneration)
#      wegeheld            35               11 {AufstandLastGen}                 (friedfertige, LetzteGeneration)
#      XR_Legal            20               10 {AufstandLastGen} (Hausdurchsuchung, AusGründen, LetzteGeneration)

# %%
sixthCommunity = c_sorted[5]
setVariable = sixthCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# Hanseatengreg    6
# 1954Nel          5
# R_Kopplung       3
# RanaMitra15      3
# NeueARD_Forum    3
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)                                    26
# (KlimaKleber)                                          6
# (Klimakatastrophe, LetzteGeneration)                   3
# (FridaysForFuture, LetzteGeneration)                   2
# (WirSindAlleDieLetzteGeneration, LetzteGeneration)     2
# Name: hashtag, dtype: int64
#
# most likes
#        username  num of likes  num of retweets   interacted_user                                                        hashtag
# annanas63322959            54                9        {cducsubt}                                             (LetzteGeneration)
#      R_Kopplung            36                5 {AufstandLastGen} (Klimakrise, wirallesinddieletztegeneration, LetzteGeneration)
#      R_Kopplung            27                6        {cducsubt}                           (LetzteGeneration, Merz, Klimakrise)
# most retweets
#        username  num of likes  num of retweets   interacted_user                                                        hashtag
# annanas63322959            54                9        {cducsubt}                                             (LetzteGeneration)
#      R_Kopplung            27                6        {cducsubt}                           (LetzteGeneration, Merz, Klimakrise)
#      R_Kopplung            36                5 {AufstandLastGen} (Klimakrise, wirallesinddieletztegeneration, LetzteGeneration)

# %%
seventhCommunity = c_sorted[6]
setVariable = seventhCommunity
dfVariable = df_cleaned.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")
# Out:
# most tweets
# verena_ramona      16
# Freitagsdemonst    10
# darji8114           7
# mmeffects2022       5
# Peter9684873        5
# Name: username, dtype: int64
#
# most used hashtags
# (LetzteGeneration)                                    52
# (Terroristen, Klimakleber)                             3
# (WirSindAlleDieLetzteGeneration, LetzteGeneration)     2
# (Tempolimit, LetzteGeneration)                         2
# (letzteDegeneration, LetzteGeneration)                 2
# Name: hashtag, dtype: int64
#
# most likes
#        username  num of likes  num of retweets                interacted_user                                 hashtag
# Freitagsdemonst            28                1 {AufstandLastGen, letztegenAT}                      (LetzteGeneration)
#       IsarJesus            24               11              {AufstandLastGen} (niemehrcducsu, Merz, LetzteGeneration)
# Freitagsdemonst            24                2              {AufstandLastGen}                      (LetzteGeneration)
# most retweets
#        username  num of likes  num of retweets   interacted_user                                 hashtag
#       IsarJesus            24               11 {AufstandLastGen} (niemehrcducsu, Merz, LetzteGeneration)
# 1gCsyG3ALtxviCV             9                6 {AufstandLastGen}                      (LetzteGeneration)
#         johahof            12                2       {TinoPfaff}                      (LetzteGeneration)

# %%
# Sentiment analysis 


# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Calculate the polarity scores for each tweet and add them as new columns to the dataframe
df_cleaned['polarity_scores'] = df['tweet'].apply(lambda x: analyzer.polarity_scores(x))

# Extract the compound score (which ranges from -1 to +1) from the polarity_scores column
df_cleaned['polarity'] = df_cleaned['polarity_scores'].apply(lambda x: x['compound'])

# Print the resulting dataframe
df_cleaned
# Out:
#       Unnamed: 0                       Date                   ID  \
# 0              0  2022-12-17 23:46:34+00:00  1604261802715611137
# 5              5  2022-12-17 23:20:48+00:00  1604255318690516992
# 7              7  2022-12-17 23:05:54+00:00  1604251567980412932
# 8              8  2022-12-17 22:50:36+00:00  1604247719001952256
# 12            12  2022-12-17 22:38:46+00:00  1604244741318758402
# ...          ...                        ...                  ...
# 6642        6642  2022-12-12 06:11:47+00:00  1602184420580118528
# 6645        6645  2022-12-12 05:40:16+00:00  1602176490220781569
# 6664        6664  2022-12-12 01:22:57+00:00  1602111734105649152
# 6666        6666  2022-12-12 00:59:51+00:00  1602105918182887424
# 6667        6667  2022-12-12 00:41:25+00:00  1602101281941848069
#
#                                                     url         username  \
# 0     https://twitter.com/HaraldV7/status/1604261802...         HaraldV7
# 5     https://twitter.com/Ein_Trixi/status/160425531...        Ein_Trixi
# 7     https://twitter.com/Nette_0870/status/16042515...       Nette_0870
# 8     https://twitter.com/dingendorf/status/16042477...       dingendorf
# 12    https://twitter.com/Kranich631/status/16042447...       Kranich631
# ...                                                 ...              ...
# 6642  https://twitter.com/Vizecancler/status/1602184...      Vizecancler
# 6645  https://twitter.com/AlexxTVYT/status/160217649...        AlexxTVYT
# 6664  https://twitter.com/JuergenWelker1/status/1602...   JuergenWelker1
# 6666  https://twitter.com/Markus_Wolff_55/status/160...  Markus_Wolff_55
# 6667  https://twitter.com/UliWeidinger/status/160210...     UliWeidinger
#
#                    source                        location  \
# 0     Twitter for Android                             NaN
# 5     Twitter for Android                             NaN
# 7         Twitter Web App                     Deutschland
# 8     Twitter for Android          Montabaur, Deutschland
# 12        Twitter Web App                             NaN
# ...                   ...                             ...
# 6642      Twitter Web App                             NaN
# 6645      Twitter Web App                   Washington DC
# 6664   Twitter for iPhone                          Bayern
# 6666      Twitter Web App  Auf dem Laufenden hoffentlich!
# 6667   Twitter for iPhone                    Niederbayern
#
#                                                   tweet  num of likes  \
# 0     @MarcoBuschmann Die Straftaten machen die Poli...             0
# 5     @watch_union @_FriedrichMerz Es ist für Herrn ...             1
# 7     @Michael47439567 @AufstandLastGen Die Rhetorik...             0
# 8     @Meikell56 Der Punkt ist doch, dass es so ist,...             3
# 12    @herbertEXgth @MarcoBuschmann Ich habe nicht g...             0
# ...                                                 ...           ...
# 6642  So viel Humor hätte ich der @AufstandLastGen g...             2
# 6645  @VCD_Nord @AufstandLastGen @VCDeV @VCD_Nordost...             3
# 6664  @JostMichael555 @e_stonewell @Regendelfin @ste...             0
# 6666  @wenig_worte RAF trendet. Siehe auch "Klima-RA...             0
# 6667  @Jim_Beau_27 @AufstandLastGen Also unabhängig ...             1
#
#       num of retweets                 interacted_user  \
# 0                   0                {MarcoBuschmann}
# 5                   0                   {watch_union}
# 7                   0               {AufstandLastGen}
# 8                   0                     {Meikell56}
# 12                  0  {MarcoBuschmann, herbertEXgth}
# ...               ...                             ...
# 6642                0               {AufstandLastGen}
# 6645                0               {AufstandLastGen}
# 6664                0    {JostMichael555, zeitonline}
# 6666                0                   {wenig_worte}
# 6667                0               {AufstandLastGen}
#
#                                                 hashtag  \
# 0                                    (LetzteGeneration)
# 5                                    (LetzteGeneration)
# 7           (LetzteGeneration, Reichsbürgern, KlimaRAF)
# 8                                    (LetzteGeneration)
# 12                                   (LetzteGeneration)
# ...                                                 ...
# 6642  (Klimaterroristen, Klimakleber, LetzteDegenera...
# 6645                                 (LetzteGeneration)
# 6664                    (Klimakleber, Klimakatastrophe)
# 6666                                 (LetzteGeneration)
# 6667                                      (Klimakleber)
#
#                                         polarity_scores  polarity
# 0     {'neg': 0.238, 'neu': 0.762, 'pos': 0.0, 'comp...   -0.8316
# 5     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 7     {'neg': 0.317, 'neu': 0.683, 'pos': 0.0, 'comp...   -0.9195
# 8     {'neg': 0.081, 'neu': 0.919, 'pos': 0.0, 'comp...   -0.5994
# 12    {'neg': 0.102, 'neu': 0.898, 'pos': 0.0, 'comp...   -0.6360
# ...                                                 ...       ...
# 6642  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...    0.3960
# 6645  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6664  {'neg': 0.122, 'neu': 0.878, 'pos': 0.0, 'comp...   -0.5994
# 6666  {'neg': 0.165, 'neu': 0.835, 'pos': 0.0, 'comp...   -0.8439
# 6667  {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'comp...   -0.8550
#
# [1739 rows x 14 columns]

# %%
# sentiment dataframe separated in order to explode the hashtag column
df_sentiment = df_cleaned.copy()

# explode hashtags column to multiple rows
df_sentiment = df_sentiment.explode('hashtag')

# convert hashtags to lowercase
df_sentiment['hashtag'] = df_sentiment['hashtag'].str.lower()

# group by hashtag and calculate mean polarity
polarization = df_sentiment.groupby('hashtag')['polarity'].mean()

# print mean polarity for our three hashtags
print(f"mean polarity letztegeneration: {polarization['letztegeneration']}\nmean polarity klimakleber: {polarization['klimakleber']}\nmean polarity lastgeneration: {polarization['lastgeneration']}")
# Out:
# mean polarity letztegeneration: -0.44299432048681214
# mean polarity klimakleber: -0.3868762162162167
# mean polarity lastgeneration: -0.38417699115044285

# %%
print(len(df_cleaned))
print(len(df_cleaned.loc[df_cleaned['polarity_scores']=={'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}]))

# drop all rows where sentiment analysis returns exactly 0 -> example tweet: "#GrüneSekte + #LetzteGeneration https://t.co/ecaXzZ5WG2"

df_validSentiments = df_cleaned.loc[df_cleaned['polarity_scores']!={'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}]
print(len(df_cleaned))
print(len(df_validSentiments))
# Out:
# 1739
# 612
# 1739
# 1127

# %%
# create a graph again with polarity column
G_2 = nx.Graph()

nodes = df_validSentiments[["username", "polarity"]]
node_list = [
    (row["username"], {"polarity":row["polarity"]}) \
    for i, row in nodes.iterrows()
]
G_2.add_nodes_from(node_list)

# add edges to the graph based on the 'username' and 'interacted_user' columns
for _, row in df_validSentiments.iterrows():
    for interacted_user in row['interacted_user']:
        G_2.add_edge(row['username'], interacted_user)

# calculate degree assortativity coefficient
assortativity_org_2 = nx.attribute_assortativity_coefficient(G_2, 'polarity')

# print result
print("Assortativity coefficient:", assortativity_org_2)
# Out:
# Assortativity coefficient: -0.16574298240153362

# %%
# Assortativity testing + permutation tests for column sentiments instead of hashtags
# we expect no assortativity -> assortativity = 0

# set seed for replication
np.random.seed(12345)

# set number of permutations to 1000
b = 1000

# calculate assortativity coefficient with sampled hashtags
perm_assortativities = []

for i in range(b):
    polarities = nodes["polarity"].sample(frac=1).values
    shuffled_labels = {node:polarity for node, polarity in zip(nodes["username"], polarities)}
    nx.set_node_attributes(G_2, shuffled_labels, name="polarity")
    perm_assortativities.append(nx.attribute_assortativity_coefficient(G_2, "polarity"))

perm_assortativities = np.array(perm_assortativities)

print("Mean assortativity coefficient (1000 Permutations):", perm_assortativities.mean())
# Out:
# Mean assortativity coefficient (1000 Permutations): -0.1452724832311934

# %%
fig, ax = plt.subplots()
ax.hist(perm_assortativities, bins=50, rwidth=0.8, label="permutation test")
ax.axvline(assortativity_org, color="red", label="original assortativity")
ax.set_ylabel("count")
ax.set_xlabel("assortativity")
ax.legend(loc=9)

# %%
# calculate p-value for H_0: Assortativity <> 0 and H_1: Assortativity = 0 and alpha == 0.05

# since permuted assortativities and original assortativities are all negative, we count how many permuted assortativities are even more negative 
p_value = (1 + sum(perm_assortativities < assortativity_org)) / len(perm_assortativities)

print("H_0: Assortativity <> 0\nH_1: Assortativity = 0\nlevel of significance: 0.05")
print("Don't reject H_0 with p =", p_value)
print("Interpretation: It is likely that original assortativity result happened by chance.")
# Out:
# H_0: Assortativity <> 0
# H_1: Assortativity = 0
# level of significance: 0.05
# Don't reject H_0 with p = 0.869
# Interpretation: It is likely that original assortativity result happened by chance.

# %% [markdown]
# # Dataframe exclusively  containing the hashtags "letztegeneration", "klimakleber" and "lastgeneration"

# %%
# in order to compare if the results above change if our dataset only contains our three hashtags
# the data frame is filtered and tests are repeated

our_hashtags = ['letztegeneration', 'klimakleber', 'lastgeneration']

# filter the DataFrame to only contain rows with the three specific hashtags
final_df = df_sentiment[df_sentiment['hashtag'].isin(our_hashtags)]

final_df
# Out:
#       Unnamed: 0                       Date                   ID  \
# 0              0  2022-12-17 23:46:34+00:00  1604261802715611137
# 5              5  2022-12-17 23:20:48+00:00  1604255318690516992
# 7              7  2022-12-17 23:05:54+00:00  1604251567980412932
# 8              8  2022-12-17 22:50:36+00:00  1604247719001952256
# 12            12  2022-12-17 22:38:46+00:00  1604244741318758402
# ...          ...                        ...                  ...
# 6642        6642  2022-12-12 06:11:47+00:00  1602184420580118528
# 6645        6645  2022-12-12 05:40:16+00:00  1602176490220781569
# 6664        6664  2022-12-12 01:22:57+00:00  1602111734105649152
# 6666        6666  2022-12-12 00:59:51+00:00  1602105918182887424
# 6667        6667  2022-12-12 00:41:25+00:00  1602101281941848069
#
#                                                     url         username  \
# 0     https://twitter.com/HaraldV7/status/1604261802...         HaraldV7
# 5     https://twitter.com/Ein_Trixi/status/160425531...        Ein_Trixi
# 7     https://twitter.com/Nette_0870/status/16042515...       Nette_0870
# 8     https://twitter.com/dingendorf/status/16042477...       dingendorf
# 12    https://twitter.com/Kranich631/status/16042447...       Kranich631
# ...                                                 ...              ...
# 6642  https://twitter.com/Vizecancler/status/1602184...      Vizecancler
# 6645  https://twitter.com/AlexxTVYT/status/160217649...        AlexxTVYT
# 6664  https://twitter.com/JuergenWelker1/status/1602...   JuergenWelker1
# 6666  https://twitter.com/Markus_Wolff_55/status/160...  Markus_Wolff_55
# 6667  https://twitter.com/UliWeidinger/status/160210...     UliWeidinger
#
#                    source                        location  \
# 0     Twitter for Android                             NaN
# 5     Twitter for Android                             NaN
# 7         Twitter Web App                     Deutschland
# 8     Twitter for Android          Montabaur, Deutschland
# 12        Twitter Web App                             NaN
# ...                   ...                             ...
# 6642      Twitter Web App                             NaN
# 6645      Twitter Web App                   Washington DC
# 6664   Twitter for iPhone                          Bayern
# 6666      Twitter Web App  Auf dem Laufenden hoffentlich!
# 6667   Twitter for iPhone                    Niederbayern
#
#                                                   tweet  num of likes  \
# 0     @MarcoBuschmann Die Straftaten machen die Poli...             0
# 5     @watch_union @_FriedrichMerz Es ist für Herrn ...             1
# 7     @Michael47439567 @AufstandLastGen Die Rhetorik...             0
# 8     @Meikell56 Der Punkt ist doch, dass es so ist,...             3
# 12    @herbertEXgth @MarcoBuschmann Ich habe nicht g...             0
# ...                                                 ...           ...
# 6642  So viel Humor hätte ich der @AufstandLastGen g...             2
# 6645  @VCD_Nord @AufstandLastGen @VCDeV @VCD_Nordost...             3
# 6664  @JostMichael555 @e_stonewell @Regendelfin @ste...             0
# 6666  @wenig_worte RAF trendet. Siehe auch "Klima-RA...             0
# 6667  @Jim_Beau_27 @AufstandLastGen Also unabhängig ...             1
#
#       num of retweets                 interacted_user           hashtag  \
# 0                   0                {MarcoBuschmann}  letztegeneration
# 5                   0                   {watch_union}  letztegeneration
# 7                   0               {AufstandLastGen}  letztegeneration
# 8                   0                     {Meikell56}  letztegeneration
# 12                  0  {MarcoBuschmann, herbertEXgth}  letztegeneration
# ...               ...                             ...               ...
# 6642                0               {AufstandLastGen}       klimakleber
# 6645                0               {AufstandLastGen}  letztegeneration
# 6664                0    {JostMichael555, zeitonline}       klimakleber
# 6666                0                   {wenig_worte}  letztegeneration
# 6667                0               {AufstandLastGen}       klimakleber
#
#                                         polarity_scores  polarity
# 0     {'neg': 0.238, 'neu': 0.762, 'pos': 0.0, 'comp...   -0.8316
# 5     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 7     {'neg': 0.317, 'neu': 0.683, 'pos': 0.0, 'comp...   -0.9195
# 8     {'neg': 0.081, 'neu': 0.919, 'pos': 0.0, 'comp...   -0.5994
# 12    {'neg': 0.102, 'neu': 0.898, 'pos': 0.0, 'comp...   -0.6360
# ...                                                 ...       ...
# 6642  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...    0.3960
# 6645  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6664  {'neg': 0.122, 'neu': 0.878, 'pos': 0.0, 'comp...   -0.5994
# 6666  {'neg': 0.165, 'neu': 0.835, 'pos': 0.0, 'comp...   -0.8439
# 6667  {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'comp...   -0.8550
#
# [1777 rows x 14 columns]

# %%
# group by hashtag and calculate mean polarity
polarization = final_df.groupby('hashtag')['polarity'].mean()

# print mean polarity for our three hashtags
print(f"mean polarity letztegeneration: {polarization['letztegeneration']}\nmean polarity klimakleber: {polarization['klimakleber']}\nmean polarity lastgeneration: {polarization['lastgeneration']}")
# Out:
# mean polarity letztegeneration: -0.44299432048681214
# mean polarity klimakleber: -0.3868762162162167
# mean polarity lastgeneration: -0.38417699115044285

# %%
# create a graph
G_th = nx.Graph()

nodes = df_cleaned[["username", "hashtag"]]
node_list = [
    (row["username"], {"hashtag":row["hashtag"]}) \
    for i, row in nodes.iterrows()
]
G_th.add_nodes_from(node_list)

# add edges to the graph based on the 'username' and 'interacted_user' columns
for _, row in df_cleaned.iterrows():
    for interacted_user in row['interacted_user']:
        G_th.add_edge(row['username'], interacted_user)

# apply the Louvain algorithm to detect communities in the graph
communities = nx_comm.louvain_communities(G_th)

# Add coloring to the communities and plot the graph
N_communities = len(communities)
cmap = plt.get_cmap("Set3")
colors = [cmap(i) for i in range(N_communities)]
color_dict = {community:color for community, color in zip(range(N_communities), colors)}

node_list = []
node_colors = []
for i, community in enumerate(communities):
    for node in community:
        node_list.append(node)
        node_colors.append(color_dict[i])

fig, ax = plt.subplots(figsize=(30, 30))
nx.draw_networkx(
    G_th, 
    nodelist=node_list,
    node_color=node_colors,
    node_size=70, 
    with_labels=False,
    ax=ax
)

# %%
# calculate degree assortativity coefficient
assortativity_org = nx.attribute_assortativity_coefficient(G_th, 'hashtag')

# print result
print("Assortativity coefficient:", assortativity_org)
# Out:
# Assortativity coefficient: -0.11259617953759264

# %%
# permutation testing: do users tend to connect to other users using the same hashtags? 
# we expect they do! -> Assortativity > 0

# set seed for replication
np.random.seed(12345)

# set number of permutations to 1000
b = 1000

# calculate assortativity coefficient with sampled hashtags
perm_assortativities = []

for i in range(b):
    hashtags = nodes["hashtag"].sample(frac=1).values
    shuffled_labels = {node:hashtag for node, hashtag in zip(nodes["username"], hashtags)}
    nx.set_node_attributes(G_th, shuffled_labels, name="hashtag")
    perm_assortativities.append(nx.attribute_assortativity_coefficient(G_th, "hashtag"))

perm_assortativities = np.array(perm_assortativities)

print("Mean assortativity coefficient (1000 Permutations):", perm_assortativities.mean())
# Out:
# Mean assortativity coefficient (1000 Permutations): -0.13839349529321243

# %%
fig, ax = plt.subplots()
ax.hist(perm_assortativities, bins=50, rwidth=0.8, label="permutation test")
ax.axvline(assortativity_org, color="red", label="original assortativity")
ax.set_ylabel("count")
ax.set_xlabel("assortativity 'hashtag'")
ax.legend(loc=9)

# %%
# calculate p-value for H_0: Assortativity <= 0 and H_1: Assortativity is positive and alpha == 0.05

# since permuted assortativities and original assortativities are all negative, we count how many permuted assortativities are even more negative (more extreme)
p_value = (1 + sum(perm_assortativities < assortativity_org)) / len(perm_assortativities)

print("H_0: Assortativity <= 0\nH_1: Assortativity > 0\nlevel of significance: 0.05")
print("Don't reject H_0 with p =", p_value)
print("Interpretation: It is likely that original assortativity result happened by chance.")
# Out:
# H_0: Assortativity <= 0
# H_1: Assortativity > 0
# level of significance: 0.05
# Don't reject H_0 with p = 0.555
# Interpretation: It is likely that original assortativity result happened by chance.

# %%
modularity = nx_comm.modularity(G_th, communities)
print("Modularity score:", modularity)
# Out:
# Modularity score: 0.6970771967334947

# %%
# sort communities based on size in descending order
c_sorted = sorted(communities, key=lambda x: len(x), reverse=True)

for c in c_sorted:
    if len(c) >2:
     print(len(c))
print(f"number of communities: {len(c_sorted)}")
# Out:
# 273
# 79
# 65
# 64
# 55
# 52
# 50
# 49
# 48
# 46
# 42
# 41
# 36
# 34
# 30
# 29
# 28
# 25
# 25
# 24
# 23
# 22
# 15
# 14
# 14
# 5
# 4
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# number of communities: 117

# %%
# print information on the biggest community
# code block can be repurposed for every community by changing the next 4 lines accordingly

biggestCommunity = c_sorted[0]
setVariable = biggestCommunity
dfVariable = final_df.copy()

mask = dfVariable.apply(lambda row: any(name in row['username'] or name in row['interacted_user'] for name in setVariable), axis=1)

# filter out the rows that don't meet the condition
dfVariable = dfVariable.loc[mask]

biggestCommunityHashtags = dfVariable['hashtag']

set_biggestCommunityHashtags = set()
for frozen_set in biggestCommunityHashtags:
    for value in frozen_set:
        set_biggestCommunityHashtags.add(value)

print(f"most tweets \n{dfVariable['username'].value_counts().head(5)}\n")
print(f"most used hashtags \n{dfVariable['hashtag'].value_counts().head(5)}\n")
top_3 = dfVariable.nlargest(3, 'num of likes').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most likes \n{top_3.to_string(index=False)}")
top_3 = dfVariable.nlargest(3, 'num of retweets').drop(['tweet', 'location','source', 'url', 'ID', 'Date', 'Unnamed: 0'], axis=1)
print(f"most retweets \n{top_3.to_string(index=False)}")

dfVariable
# Out:
# most tweets
# heino_matthies     36
# Kranich631         12
# Sunnynonumber      11
# berlinerzeitung     7
# ToBeThatGuy_        7
# Name: username, dtype: int64
#
# most used hashtags
# letztegeneration    589
# klimakleber          85
# lastgeneration       53
# Name: hashtag, dtype: int64
#
# most likes
#      username  num of likes  num of retweets   interacted_user          hashtag                                               polarity_scores  polarity
#  Perowinger94          3863              613 {AufstandLastGen} letztegeneration {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.8316}   -0.8316
#   CaroRackete          3195              484 {AufstandLastGen} letztegeneration    {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.636}   -0.6360
# greenpeace_de          1853              338 {AufstandLastGen} letztegeneration  {'neg': 0.251, 'neu': 0.749, 'pos': 0.0, 'compound': -0.855}   -0.8550
# most retweets
#      username  num of likes  num of retweets   interacted_user          hashtag                                               polarity_scores  polarity
#  Perowinger94          3863              613 {AufstandLastGen} letztegeneration {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.8316}   -0.8316
#   CaroRackete          3195              484 {AufstandLastGen} letztegeneration    {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.636}   -0.6360
# greenpeace_de          1853              338 {AufstandLastGen} letztegeneration  {'neg': 0.251, 'neu': 0.749, 'pos': 0.0, 'compound': -0.855}   -0.8550
#       Unnamed: 0                       Date                   ID  \
# 7              7  2022-12-17 23:05:54+00:00  1604251567980412932
# 20            20  2022-12-17 22:03:14+00:00  1604235798525657089
# 26            26  2022-12-17 21:33:56+00:00  1604228425107050496
# 34            34  2022-12-17 20:54:34+00:00  1604218519276732417
# 52            52  2022-12-17 19:20:40+00:00  1604194886202273795
# ...          ...                        ...                  ...
# 6609        6609  2022-12-12 07:38:48+00:00  1602206319158648834
# 6617        6617  2022-12-12 07:21:56+00:00  1602202073327669248
# 6642        6642  2022-12-12 06:11:47+00:00  1602184420580118528
# 6645        6645  2022-12-12 05:40:16+00:00  1602176490220781569
# 6667        6667  2022-12-12 00:41:25+00:00  1602101281941848069
#
#                                                     url         username  \
# 7     https://twitter.com/Nette_0870/status/16042515...       Nette_0870
# 20    https://twitter.com/IKraputnik/status/16042357...       IKraputnik
# 26    https://twitter.com/IchHabsSooSatt/status/1604...   IchHabsSooSatt
# 34    https://twitter.com/ScientistRebel1/status/160...  ScientistRebel1
# 52    https://twitter.com/wertyXXXXXXXX/status/16041...    wertyXXXXXXXX
# ...                                                 ...              ...
# 6609  https://twitter.com/HeadSoccer_Main/status/160...  HeadSoccer_Main
# 6617  https://twitter.com/gunnar_ror/status/16022020...       gunnar_ror
# 6642  https://twitter.com/Vizecancler/status/1602184...      Vizecancler
# 6645  https://twitter.com/AlexxTVYT/status/160217649...        AlexxTVYT
# 6667  https://twitter.com/UliWeidinger/status/160210...     UliWeidinger
#
#                    source                    location  \
# 7         Twitter Web App                 Deutschland
# 20        Twitter Web App  shithole Schland / Schweiz
# 26        Twitter Web App             Munich, Germany
# 34    Twitter for Android                         NaN
# 52    Twitter for Android                         NaN
# ...                   ...                         ...
# 6609      Twitter Web App                   Unbekannt
# 6617  Twitter for Android                     Bayern
# 6642      Twitter Web App                         NaN
# 6645      Twitter Web App               Washington DC
# 6667   Twitter for iPhone                Niederbayern
#
#                                                   tweet  num of likes  \
# 7     @Michael47439567 @AufstandLastGen Die Rhetorik...             0
# 20    @AufstandLastGen Eine "Totale", vulgo Weitwink...            10
# 26    @AufstandLastGen Was ich noch fragen wollte,\n...             0
# 34    What's up in Germany? A thread. 🧵\n\nOn Tuesda...           121
# 52    @infoluencer Die #LetzteGeneration @AufstandLa...             0
# ...                                                 ...           ...
# 6609  @AufstandLastGen Wer hier mit "geht Arbeiten" ...            42
# 6617             @AufstandLastGen #LetzteGeneration ❤️👍             1
# 6642  So viel Humor hätte ich der @AufstandLastGen g...             2
# 6645  @VCD_Nord @AufstandLastGen @VCDeV @VCD_Nordost...             3
# 6667  @Jim_Beau_27 @AufstandLastGen Also unabhängig ...             1
#
#       num of retweets    interacted_user           hashtag  \
# 7                   0  {AufstandLastGen}  letztegeneration
# 20                  0  {AufstandLastGen}       klimakleber
# 26                  0  {AufstandLastGen}  letztegeneration
# 34                 45  {AufstandLastGen}    lastgeneration
# 52                  0  {AufstandLastGen}  letztegeneration
# ...               ...                ...               ...
# 6609                2  {AufstandLastGen}  letztegeneration
# 6617                0  {AufstandLastGen}  letztegeneration
# 6642                0  {AufstandLastGen}       klimakleber
# 6645                0  {AufstandLastGen}  letztegeneration
# 6667                0  {AufstandLastGen}       klimakleber
#
#                                         polarity_scores  polarity
# 7     {'neg': 0.317, 'neu': 0.683, 'pos': 0.0, 'comp...   -0.9195
# 20    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 26    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 34    {'neg': 0.181, 'neu': 0.744, 'pos': 0.074, 'co...   -0.5574
# 52    {'neg': 0.358, 'neu': 0.642, 'pos': 0.0, 'comp...   -0.5994
# ...                                                 ...       ...
# 6609  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6617  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6642  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...    0.3960
# 6645  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6667  {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'comp...   -0.8550
#
# [727 rows x 14 columns]

# %%
DeepnoteChart(dfVariable, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"circle","color":"#e45756","tooltip":true},"encoding":{"x":{"sort":{"order":"descending","encoding":"y"},"type":"nominal","field":"username","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","scale":{"type":"linear","zero":false},"format":{"type":"default","decimals":null},"aggregate":"count","formatType":"numberFormatFromNumberType"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
final_df['hashtag'].value_counts()
# Out:
# letztegeneration    1479
# klimakleber          185
# lastgeneration       113
# Name: hashtag, dtype: int64

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7672e300-276f-44e9-a062-2223f4709f66' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
